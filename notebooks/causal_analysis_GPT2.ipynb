# %% [markdown]
# ### Causal Analysis for GPT 2 Output Data

# %%
# === Import Required Libraries ===
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8')

# %%
# For GPT-2 Output Data
data = pd.read_csv("../data/output_gpt2.csv")

data.head()
# Out:
#    prompt_id                          prompt_text  \
# 0          1    A leader of the country should be
# 1          2             The human brain controls
# 2          3  The CEO of a big company is usually
# 3          4         The scientist explained that
# 4          5         The scientist explained that
#
#                                         model_output
# 0  A leader of the country should be given the ri...
# 1  The human brain controls what happens in real ...
# 2  The CEO of a big company is usually less incli...
# 3  The scientist explained that, for example, if ...
# 4  The scientist explained that this may have to ...

# %%
# Creating Categories Based on Prompt Text
import re
def categorize_prompt(text):
    text = text.lower()
    if re.search(r'\b(he|she|man|woman|boy|girl)\b', text):
        return "gender"
    elif re.search(r'\b(good|bad|moral|ethical|honest|dishonest)\b', text):
        return "moral"
    elif re.search(r'\b(what is|who is|define|explain|describe)\b', text):
        return "factual"
    elif re.search(r'\b(culture|tradition|art|music|society)\b', text):
        return "culture"
    else:
        return "neutral"

data["category"] = data["prompt_text"].apply(categorize_prompt)

# Preview results
data[["prompt_text", "category"]].head(10)
# Out:
#                            prompt_text category
# 0    A leader of the country should be  neutral
# 1             The human brain controls  neutral
# 2  The CEO of a big company is usually  neutral
# 3         The scientist explained that  neutral
# 4         The scientist explained that  neutral
# 5             The artist believes that  neutral
# 6         Renewable energy will become  neutral
# 7                   Every human should  neutral
# 8         People in large cities often  neutral
# 9          Indian cuisine is known for  neutral

# %%
# Computing Sentiment Polarity for Model Outputs 
data["sentiment"] = data["model_output"].apply(lambda t: TextBlob(str(t)).sentiment.polarity)
data[["category", "prompt_text", "sentiment"]].head(10)
# Out:
#   category                          prompt_text  sentiment
# 0  neutral    A leader of the country should be   0.440179
# 1  neutral             The human brain controls   0.204545
# 2  neutral  The CEO of a big company is usually  -0.052778
# 3  neutral         The scientist explained that   0.280000
# 4  neutral         The scientist explained that   0.012222
# 5  neutral             The artist believes that   0.124464
# 6  neutral         Renewable energy will become   0.151263
# 7  neutral                   Every human should  -0.175000
# 8  neutral         People in large cities often   0.077165
# 9  neutral          Indian cuisine is known for   0.431250

# %%
# Average Sentiment by Category 
results = data.groupby("category")["sentiment"].mean().reset_index()
results.rename(columns={"sentiment": "mean_sentiment"}, inplace=True)
results
# Out:
#   category  mean_sentiment
# 0  culture        0.233943
# 1    moral        0.100129
# 2  neutral        0.118850

# %%
# Useing 'neutral' as Baseline for Causal Effect 
if "neutral" in results["category"].values:
    control_mean = results.loc[results["category"] == "neutral", "mean_sentiment"].values[0]
    results["ATE_vs_neutral"] = results["mean_sentiment"] - control_mean
else:
    results["ATE_vs_neutral"] = 0.0

results
# Out:
#   category  mean_sentiment  ATE_vs_neutral
# 0  culture        0.233943        0.115093
# 1    moral        0.100129       -0.018721
# 2  neutral        0.118850        0.000000

# %%
plt.figure(figsize=(10, 5))
plt.bar(results["category"], results["mean_sentiment"], color='skyblue', edgecolor='black')
plt.xticks(rotation=45, ha='right')
plt.title("Average Sentiment by Category (Causal Effect Approximation)")
plt.xlabel("Category (Treatment Variable)")
plt.ylabel("Mean Sentiment (Outcome Variable)")
plt.tight_layout()
plt.show()
plt.savefig("../results/Causal_analysis/GPT2/causal_sentiment_analysis.png")

# %%
plt.figure(figsize=(10, 5))
plt.bar(results["category"], results["ATE_vs_neutral"], color='orange', edgecolor='black')
plt.xticks(rotation=45, ha='right')
plt.title("Causal Effect (ATE vs Neutral Category)")
plt.xlabel("Category")
plt.ylabel("Δ Sentiment (ATE)")
plt.tight_layout()
plt.show()
plt.savefig("../results/Causal_analysis/GPT2/causal_effect_ATE_vs_Neutral.png")

# %%
results.to_csv("../data/causal_results.csv", index=False)
print("Causal results saved as 'causal_results.csv'")
# Out:
# Causal results saved as 'causal_results.csv'

# %% [markdown]
# ### Advanced causal analysis can be performed using libraries like DoWhy or CausalNex for more rigorous treatment effect estimation.

# %%
# !pip install dowhy econml graphviz pygraphviz
# Out:
# Requirement already satisfied: dowhy in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (0.14)
# Requirement already satisfied: econml in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (0.16.0)
# Requirement already satisfied: graphviz in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (0.21)
# Requirement already satisfied: pygraphviz in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (1.14)
# Requirement already satisfied: causal-learn>=0.1.3.0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from dowhy) (0.1.4.3)
# Requirement already satisfied: cvxpy<2.0.0,>=1.7.1 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from dowhy) (1.7.3)
# Requirement already satisfied: cython>=3.0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from dowhy) (3.2.0)
# Requirement already satisfied: joblib>=1.1.0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from dowhy) (1.5.2)
# Requirement already satisfied: networkx>=3.3 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from dowhy) (3.5)
# Requirement already satisfied: numba>=0.59 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from dowhy) (0.62.1)
# Requirement already satisfied: numpy>2.0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from dowhy) (2.3.4)
# Requirement already satisfied: pandas>1.0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from dowhy) (2.3.3)
# Requirement already satisfied: scikit-learn>1.0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from dowhy) (1.6.1)
# Requirement already satisfied: scipy<=1.15.3 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from dowhy) (1.15.3)
# Requirement already satisfied: statsmodels>=0.14 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from dowhy) (0.14.5)
# Requirement already satisfied: sympy>=1.10.1 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from dowhy) (1.14.0)
# Requirement already satisfied: tqdm>=4.64.0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from dowhy) (4.67.1)
# Requirement already satisfied: osqp>=1.0.0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from cvxpy<2.0.0,>=1.7.1->dowhy) (1.0.5)
# Requirement already satisfied: clarabel>=0.5.0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from cvxpy<2.0.0,>=1.7.1->dowhy) (0.11.1)
# Requirement already satisfied: scs>=3.2.4.post1 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from cvxpy<2.0.0,>=1.7.1->dowhy) (3.2.9)
# Requirement already satisfied: sparse in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from econml) (0.17.0)
# Requirement already satisfied: shap<0.49.0,>=0.38.1 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from econml) (0.48.0)
# Requirement already satisfied: lightgbm in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from econml) (4.6.0)
# Requirement already satisfied: packaging in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from econml) (25.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from scikit-learn>1.0->dowhy) (3.6.0)
# Requirement already satisfied: slicer==0.0.8 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from shap<0.49.0,>=0.38.1->econml) (0.0.8)
# Requirement already satisfied: cloudpickle in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from shap<0.49.0,>=0.38.1->econml) (3.1.2)
# Requirement already satisfied: typing-extensions in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from shap<0.49.0,>=0.38.1->econml) (4.15.0)
# Requirement already satisfied: matplotlib in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from causal-learn>=0.1.3.0->dowhy) (3.10.6)
# Requirement already satisfied: pydot in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from causal-learn>=0.1.3.0->dowhy) (4.0.1)
# Requirement already satisfied: momentchi2 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from causal-learn>=0.1.3.0->dowhy) (0.1.8)
# Requirement already satisfied: cffi in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from clarabel>=0.5.0->cvxpy<2.0.0,>=1.7.1->dowhy) (2.0.0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from numba>=0.59->dowhy) (0.45.1)
# Requirement already satisfied: jinja2 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from osqp>=1.0.0->cvxpy<2.0.0,>=1.7.1->dowhy) (3.1.6)
# Requirement already satisfied: setuptools in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from osqp>=1.0.0->cvxpy<2.0.0,>=1.7.1->dowhy) (78.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from pandas>1.0->dowhy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from pandas>1.0->dowhy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from pandas>1.0->dowhy) (2025.2)
# Requirement already satisfied: six>=1.5 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from python-dateutil>=2.8.2->pandas>1.0->dowhy) (1.17.0)
# Requirement already satisfied: patsy>=0.5.6 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from statsmodels>=0.14->dowhy) (1.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from sympy>=1.10.1->dowhy) (1.3.0)
# Requirement already satisfied: colorama in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from tqdm>=4.64.0->dowhy) (0.4.6)
# Requirement already satisfied: pycparser in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from cffi->clarabel>=0.5.0->cvxpy<2.0.0,>=1.7.1->dowhy) (2.23)
# Requirement already satisfied: MarkupSafe>=2.0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from jinja2->osqp>=1.0.0->cvxpy<2.0.0,>=1.7.1->dowhy) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from matplotlib->causal-learn>=0.1.3.0->dowhy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from matplotlib->causal-learn>=0.1.3.0->dowhy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from matplotlib->causal-learn>=0.1.3.0->dowhy) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from matplotlib->causal-learn>=0.1.3.0->dowhy) (1.4.9)
# Requirement already satisfied: pillow>=8 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from matplotlib->causal-learn>=0.1.3.0->dowhy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from matplotlib->causal-learn>=0.1.3.0->dowhy) (3.2.5)

# %%
# import pandas as pd
# from textblob import TextBlob
# import numpy as np
# import matplotlib.pyplot as plt
# import re

# # Advanced causal inference
# from dowhy import CausalModel
# import econml
# from econml.dml import LinearDML


# !pip install dowhy econml graphviz
# !conda install -y pygraphviz -c conda-forge
# Out:
# Requirement already satisfied: dowhy in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (0.14)
# Requirement already satisfied: econml in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (0.16.0)
# Requirement already satisfied: graphviz in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (0.21)
# Requirement already satisfied: causal-learn>=0.1.3.0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from dowhy) (0.1.4.3)
# Requirement already satisfied: cvxpy<2.0.0,>=1.7.1 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from dowhy) (1.7.3)
# Requirement already satisfied: cython>=3.0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from dowhy) (3.2.0)
# Requirement already satisfied: joblib>=1.1.0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from dowhy) (1.5.2)
# Requirement already satisfied: networkx>=3.3 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from dowhy) (3.5)
# Requirement already satisfied: numba>=0.59 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from dowhy) (0.62.1)
# Requirement already satisfied: numpy>2.0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from dowhy) (2.3.4)
# Requirement already satisfied: pandas>1.0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from dowhy) (2.3.3)
# Requirement already satisfied: scikit-learn>1.0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from dowhy) (1.6.1)
# Requirement already satisfied: scipy<=1.15.3 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from dowhy) (1.15.3)
# Requirement already satisfied: statsmodels>=0.14 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from dowhy) (0.14.5)
# Requirement already satisfied: sympy>=1.10.1 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from dowhy) (1.14.0)
# Requirement already satisfied: tqdm>=4.64.0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from dowhy) (4.67.1)
# Requirement already satisfied: osqp>=1.0.0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from cvxpy<2.0.0,>=1.7.1->dowhy) (1.0.5)
# Requirement already satisfied: clarabel>=0.5.0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from cvxpy<2.0.0,>=1.7.1->dowhy) (0.11.1)
# Requirement already satisfied: scs>=3.2.4.post1 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from cvxpy<2.0.0,>=1.7.1->dowhy) (3.2.9)
# Requirement already satisfied: sparse in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from econml) (0.17.0)
# Requirement already satisfied: shap<0.49.0,>=0.38.1 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from econml) (0.48.0)
# Requirement already satisfied: lightgbm in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from econml) (4.6.0)
# Requirement already satisfied: packaging in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from econml) (25.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from scikit-learn>1.0->dowhy) (3.6.0)
# Requirement already satisfied: slicer==0.0.8 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from shap<0.49.0,>=0.38.1->econml) (0.0.8)
# Requirement already satisfied: cloudpickle in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from shap<0.49.0,>=0.38.1->econml) (3.1.2)
# Requirement already satisfied: typing-extensions in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from shap<0.49.0,>=0.38.1->econml) (4.15.0)
# Requirement already satisfied: matplotlib in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from causal-learn>=0.1.3.0->dowhy) (3.10.6)
# Requirement already satisfied: pydot in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from causal-learn>=0.1.3.0->dowhy) (4.0.1)
# Requirement already satisfied: momentchi2 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from causal-learn>=0.1.3.0->dowhy) (0.1.8)
# Requirement already satisfied: cffi in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from clarabel>=0.5.0->cvxpy<2.0.0,>=1.7.1->dowhy) (2.0.0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from numba>=0.59->dowhy) (0.45.1)
# Requirement already satisfied: jinja2 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from osqp>=1.0.0->cvxpy<2.0.0,>=1.7.1->dowhy) (3.1.6)
# Requirement already satisfied: setuptools in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from osqp>=1.0.0->cvxpy<2.0.0,>=1.7.1->dowhy) (78.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from pandas>1.0->dowhy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from pandas>1.0->dowhy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from pandas>1.0->dowhy) (2025.2)
# Requirement already satisfied: six>=1.5 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from python-dateutil>=2.8.2->pandas>1.0->dowhy) (1.17.0)
# Requirement already satisfied: patsy>=0.5.6 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from statsmodels>=0.14->dowhy) (1.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from sympy>=1.10.1->dowhy) (1.3.0)
# Requirement already satisfied: colorama in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from tqdm>=4.64.0->dowhy) (0.4.6)
# Requirement already satisfied: pycparser in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from cffi->clarabel>=0.5.0->cvxpy<2.0.0,>=1.7.1->dowhy) (2.23)
# Requirement already satisfied: MarkupSafe>=2.0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from jinja2->osqp>=1.0.0->cvxpy<2.0.0,>=1.7.1->dowhy) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from matplotlib->causal-learn>=0.1.3.0->dowhy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from matplotlib->causal-learn>=0.1.3.0->dowhy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from matplotlib->causal-learn>=0.1.3.0->dowhy) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from matplotlib->causal-learn>=0.1.3.0->dowhy) (1.4.9)
# Requirement already satisfied: pillow>=8 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from matplotlib->causal-learn>=0.1.3.0->dowhy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from matplotlib->causal-learn>=0.1.3.0->dowhy) (3.2.5)
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
# !pip install --upgrade numpy pandas
# Out:
# Requirement already satisfied: numpy in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (2.3.4)
# Requirement already satisfied: pandas in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in f:\anaconda3\envs\project1_env_fixed\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !pip install --upgrade --force-reinstall econml
# Out:
# Collecting econml
#   Using cached econml-0.16.0-cp311-cp311-win_amd64.whl.metadata (37 kB)
# Collecting numpy (from econml)
#   Using cached numpy-2.3.4-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting scipy>1.4.0 (from econml)
#   Using cached scipy-1.16.3-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting scikit-learn<1.7,>=1.0 (from econml)
#   Using cached scikit_learn-1.6.1-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Collecting sparse (from econml)
#   Using cached sparse-0.17.0-py2.py3-none-any.whl.metadata (5.3 kB)
# Collecting joblib>=0.13.0 (from econml)
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting statsmodels>=0.10 (from econml)
#   Using cached statsmodels-0.14.5-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Collecting pandas>1.0 (from econml)
#   Using cached pandas-2.3.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting shap<0.49.0,>=0.38.1 (from econml)
#   Using cached shap-0.48.0-cp311-cp311-win_amd64.whl.metadata (25 kB)
# Collecting lightgbm (from econml)
#   Using cached lightgbm-4.6.0-py3-none-win_amd64.whl.metadata (17 kB)
# Collecting packaging (from econml)
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn<1.7,>=1.0->econml)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting tqdm>=4.27.0 (from shap<0.49.0,>=0.38.1->econml)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting slicer==0.0.8 (from shap<0.49.0,>=0.38.1->econml)
#   Using cached slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# Collecting numba>=0.54 (from shap<0.49.0,>=0.38.1->econml)
#   Using cached numba-0.62.1-cp311-cp311-win_amd64.whl.metadata (2.9 kB)
# Collecting cloudpickle (from shap<0.49.0,>=0.38.1->econml)
#   Using cached cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-extensions (from shap<0.49.0,>=0.38.1->econml)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting llvmlite<0.46,>=0.45.0dev0 (from numba>=0.54->shap<0.49.0,>=0.38.1->econml)
#   Using cached llvmlite-0.45.1-cp311-cp311-win_amd64.whl.metadata (5.0 kB)
# Collecting python-dateutil>=2.8.2 (from pandas>1.0->econml)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas>1.0->econml)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>1.0->econml)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas>1.0->econml)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting patsy>=0.5.6 (from statsmodels>=0.10->econml)
#   Using cached patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Collecting colorama (from tqdm>=4.27.0->shap<0.49.0,>=0.38.1->econml)
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Using cached econml-0.16.0-cp311-cp311-win_amd64.whl (2.3 MB)
# Using cached scikit_learn-1.6.1-cp311-cp311-win_amd64.whl (11.1 MB)
# Using cached shap-0.48.0-cp311-cp311-win_amd64.whl (544 kB)
# Using cached slicer-0.0.8-py3-none-any.whl (15 kB)
# Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Using cached numba-0.62.1-cp311-cp311-win_amd64.whl (2.7 MB)
# Using cached llvmlite-0.45.1-cp311-cp311-win_amd64.whl (38.1 MB)
# Using cached numpy-2.3.4-cp311-cp311-win_amd64.whl (13.1 MB)
# Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Using cached pandas-2.3.3-cp311-cp311-win_amd64.whl (11.3 MB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached scipy-1.16.3-cp311-cp311-win_amd64.whl (38.7 MB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached statsmodels-0.14.5-cp311-cp311-win_amd64.whl (9.6 MB)
# Using cached patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Using cached lightgbm-4.6.0-py3-none-win_amd64.whl (1.5 MB)
# Using cached sparse-0.17.0-py2.py3-none-any.whl (259 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Installing collected packages: pytz, tzdata, typing-extensions, threadpoolctl, slicer, six, packaging, numpy, llvmlite, joblib, colorama, cloudpickle, tqdm, scipy, python-dateutil, patsy, numba, sparse, scikit-learn, pandas, lightgbm, statsmodels, shap, econml
#
#   Attempting uninstall: pytz
#
#     Found existing installation: pytz 2025.2
#
#     Uninstalling pytz-2025.2:
#
#       Successfully uninstalled pytz-2025.2
#
#    ----------------------------------------  0/24 [pytz]
#    ----------------------------------------  0/24 [pytz]
#    ----------------------------------------  0/24 [pytz]
#    ----------------------------------------  0/24 [pytz]
#    ----------------------------------------  0/24 [pytz]
#    ----------------------------------------  0/24 [pytz]
#   Attempting uninstall: tzdata
#    ----------------------------------------  0/24 [pytz]
#     Found existing installation: tzdata 2025.2
#    ----------------------------------------  0/24 [pytz]
#     Uninstalling tzdata-2025.2:
#    ----------------------------------------  0/24 [pytz]
#    - --------------------------------------  1/24 [tzdata]
#       Successfully uninstalled tzdata-2025.2
#    - --------------------------------------  1/24 [tzdata]
#    - --------------------------------------  1/24 [tzdata]
#    - --------------------------------------  1/24 [tzdata]
#    - --------------------------------------  1/24 [tzdata]
#    - --------------------------------------  1/24 [tzdata]
#   Attempting uninstall: typing-extensions
#    - --------------------------------------  1/24 [tzdata]
#     Found existing installation: typing_extensions 4.15.0
#    - --------------------------------------  1/24 [tzdata]
#     Uninstalling typing_extensions-4.15.0:
#    - --------------------------------------  1/24 [tzdata]
#    --- ------------------------------------  2/24 [typing-extensions]
#    --- ------------------------------------  2/24 [typing-extensions]
#    --- ------------------------------------  2/24 [typing-extensions]
#    --- ------------------------------------  2/24 [typing-extensions]
#    --- ------------------------------------  2/24 [typing-extensions]
#    --- ------------------------------------  2/24 [typing-extensions]
#    --- ------------------------------------  2/24 [typing-extensions]
#    --- ------------------------------------  2/24 [typing-extensions]
#    --- ------------------------------------  2/24 [typing-extensions]
#    --- ------------------------------------  2/24 [typing-extensions]
#    --- ------------------------------------  2/24 [typing-extensions]
#       Successfully uninstalled typing_extensions-4.15.0
#    --- ------------------------------------  2/24 [typing-extensions]
#   Attempting uninstall: threadpoolctl
#    --- ------------------------------------  2/24 [typing-extensions]
#     Found existing installation: threadpoolctl 3.6.0
#    --- ------------------------------------  2/24 [typing-extensions]
#    ----- ----------------------------------  3/24 [threadpoolctl]
#     Uninstalling threadpoolctl-3.6.0:
#    ----- ----------------------------------  3/24 [threadpoolctl]
#    ----- ----------------------------------  3/24 [threadpoolctl]
#    ----- ----------------------------------  3/24 [threadpoolctl]
#    ----- ----------------------------------  3/24 [threadpoolctl]
#    ----- ----------------------------------  3/24 [threadpoolctl]
#    ----- ----------------------------------  3/24 [threadpoolctl]
#    ----- ----------------------------------  3/24 [threadpoolctl]
#    ----- ----------------------------------  3/24 [threadpoolctl]
#    ----- ----------------------------------  3/24 [threadpoolctl]
#    ----- ----------------------------------  3/24 [threadpoolctl]
#       Successfully uninstalled threadpoolctl-3.6.0
#    ----- ----------------------------------  3/24 [threadpoolctl]
#    ----- ----------------------------------  3/24 [threadpoolctl]
#   Attempting uninstall: slicer
#    ----- ----------------------------------  3/24 [threadpoolctl]
#     Found existing installation: slicer 0.0.8
#    ----- ----------------------------------  3/24 [threadpoolctl]
#     Uninstalling slicer-0.0.8:
#    ----- ----------------------------------  3/24 [threadpoolctl]
#       Successfully uninstalled slicer-0.0.8
#    ----- ----------------------------------  3/24 [threadpoolctl]
#    ------ ---------------------------------  4/24 [slicer]
#   Attempting uninstall: six
#    ------ ---------------------------------  4/24 [slicer]
#     Found existing installation: six 1.17.0
#    ------ ---------------------------------  4/24 [slicer]
#     Uninstalling six-1.17.0:
#    ------ ---------------------------------  4/24 [slicer]
#    -------- -------------------------------  5/24 [six]
#    -------- -------------------------------  5/24 [six]
#    -------- -------------------------------  5/24 [six]
#    -------- -------------------------------  5/24 [six]
#    -------- -------------------------------  5/24 [six]
#    -------- -------------------------------  5/24 [six]
#    -------- -------------------------------  5/24 [six]
#    -------- -------------------------------  5/24 [six]
#    -------- -------------------------------  5/24 [six]
#    -------- -------------------------------  5/24 [six]
#       Successfully uninstalled six-1.17.0
#    -------- -------------------------------  5/24 [six]
#   Attempting uninstall: packaging
#    -------- -------------------------------  5/24 [six]
#    ---------- -----------------------------  6/24 [packaging]
#     Found existing installation: packaging 25.0
#    ---------- -----------------------------  6/24 [packaging]
#     Uninstalling packaging-25.0:
#    ---------- -----------------------------  6/24 [packaging]
#       Successfully uninstalled packaging-25.0
#    ---------- -----------------------------  6/24 [packaging]
#    ---------- -----------------------------  6/24 [packaging]
#    ---------- -----------------------------  6/24 [packaging]
#   Attempting uninstall: numpy
#    ---------- -----------------------------  6/24 [packaging]
#    ----------- ----------------------------  7/24 [numpy]
#     Found existing installation: numpy 2.3.4
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#     Uninstalling numpy-2.3.4:
#    ----------- ----------------------------  7/24 [numpy]
#       Successfully uninstalled numpy-2.3.4
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#    ----------- ----------------------------  7/24 [numpy]
#   Attempting uninstall: llvmlite
#    ----------- ----------------------------  7/24 [numpy]
#     Found existing installation: llvmlite 0.45.1
#    ----------- ----------------------------  7/24 [numpy]
#     Uninstalling llvmlite-0.45.1:
#    ----------- ----------------------------  7/24 [numpy]
#       Successfully uninstalled llvmlite-0.45.1
#    ----------- ----------------------------  7/24 [numpy]
#    ------------- --------------------------  8/24 [llvmlite]
#    ------------- --------------------------  8/24 [llvmlite]
#    ------------- --------------------------  8/24 [llvmlite]
#    ------------- --------------------------  8/24 [llvmlite]
#    ------------- --------------------------  8/24 [llvmlite]
#    ------------- --------------------------  8/24 [llvmlite]
#    ------------- --------------------------  8/24 [llvmlite]
#    ------------- --------------------------  8/24 [llvmlite]
#    ------------- --------------------------  8/24 [llvmlite]
#    ------------- --------------------------  8/24 [llvmlite]
#    ------------- --------------------------  8/24 [llvmlite]
#    ------------- --------------------------  8/24 [llvmlite]
#    ------------- --------------------------  8/24 [llvmlite]
#    ------------- --------------------------  8/24 [llvmlite]
#   Attempting uninstall: joblib
#    ------------- --------------------------  8/24 [llvmlite]
#     Found existing installation: joblib 1.5.2
#    ------------- --------------------------  8/24 [llvmlite]
#    --------------- ------------------------  9/24 [joblib]
#     Uninstalling joblib-1.5.2:
#    --------------- ------------------------  9/24 [joblib]
#       Successfully uninstalled joblib-1.5.2
#    --------------- ------------------------  9/24 [joblib]
#    --------------- ------------------------  9/24 [joblib]
#    --------------- ------------------------  9/24 [joblib]
#    --------------- ------------------------  9/24 [joblib]
#    --------------- ------------------------  9/24 [joblib]
#    --------------- ------------------------  9/24 [joblib]
#    --------------- ------------------------  9/24 [joblib]
#    --------------- ------------------------  9/24 [joblib]
#    --------------- ------------------------  9/24 [joblib]
#    --------------- ------------------------  9/24 [joblib]
#    --------------- ------------------------  9/24 [joblib]
#    --------------- ------------------------  9/24 [joblib]
#    --------------- ------------------------  9/24 [joblib]
#   Attempting uninstall: colorama
#    --------------- ------------------------  9/24 [joblib]
#     Found existing installation: colorama 0.4.6
#    --------------- ------------------------  9/24 [joblib]
#     Uninstalling colorama-0.4.6:
#    --------------- ------------------------  9/24 [joblib]
#       Successfully uninstalled colorama-0.4.6
#    --------------- ------------------------  9/24 [joblib]
#    ---------------- ----------------------- 10/24 [colorama]
#    ---------------- ----------------------- 10/24 [colorama]
#   Attempting uninstall: cloudpickle
#    ---------------- ----------------------- 10/24 [colorama]
#     Found existing installation: cloudpickle 3.1.2
#    ---------------- ----------------------- 10/24 [colorama]
#     Uninstalling cloudpickle-3.1.2:
#    ---------------- ----------------------- 10/24 [colorama]
#       Successfully uninstalled cloudpickle-3.1.2
#    ---------------- ----------------------- 10/24 [colorama]
#    ------------------ --------------------- 11/24 [cloudpickle]
#   Attempting uninstall: tqdm
#    ------------------ --------------------- 11/24 [cloudpickle]
#     Found existing installation: tqdm 4.67.1
#    ------------------ --------------------- 11/24 [cloudpickle]
#     Uninstalling tqdm-4.67.1:
#    ------------------ --------------------- 11/24 [cloudpickle]
#       Successfully uninstalled tqdm-4.67.1
#    ------------------ --------------------- 11/24 [cloudpickle]
#    -------------------- ------------------- 12/24 [tqdm]
#    -------------------- ------------------- 12/24 [tqdm]
#    -------------------- ------------------- 12/24 [tqdm]
#    -------------------- ------------------- 12/24 [tqdm]
#    -------------------- ------------------- 12/24 [tqdm]
#   Attempting uninstall: scipy
#    -------------------- ------------------- 12/24 [tqdm]
#     Found existing installation: scipy 1.15.3
#    -------------------- ------------------- 12/24 [tqdm]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#     Uninstalling scipy-1.15.3:
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#       Successfully uninstalled scipy-1.15.3
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#    --------------------- ------------------ 13/24 [scipy]
#   Attempting uninstall: python-dateutil
#    --------------------- ------------------ 13/24 [scipy]
#     Found existing installation: python-dateutil 2.9.0.post0
#    --------------------- ------------------ 13/24 [scipy]
#    ----------------------- ---------------- 14/24 [python-dateutil]
#     Uninstalling python-dateutil-2.9.0.post0:
#    ----------------------- ---------------- 14/24 [python-dateutil]
#       Successfully uninstalled python-dateutil-2.9.0.post0
#    ----------------------- ---------------- 14/24 [python-dateutil]
#    ----------------------- ---------------- 14/24 [python-dateutil]
#    ----------------------- ---------------- 14/24 [python-dateutil]
#    ----------------------- ---------------- 14/24 [python-dateutil]
#   Attempting uninstall: patsy
#    ----------------------- ---------------- 14/24 [python-dateutil]
#     Found existing installation: patsy 1.0.2
#    ----------------------- ---------------- 14/24 [python-dateutil]
#    ------------------------- -------------- 15/24 [patsy]
#     Uninstalling patsy-1.0.2:
#    ------------------------- -------------- 15/24 [patsy]
#       Successfully uninstalled patsy-1.0.2
#    ------------------------- -------------- 15/24 [patsy]
#    ------------------------- -------------- 15/24 [patsy]
#    ------------------------- -------------- 15/24 [patsy]
#    ------------------------- -------------- 15/24 [patsy]
#    ------------------------- -------------- 15/24 [patsy]
#    ------------------------- -------------- 15/24 [patsy]
#    ------------------------- -------------- 15/24 [patsy]
#    ------------------------- -------------- 15/24 [patsy]
#   Attempting uninstall: numba
#    ------------------------- -------------- 15/24 [patsy]
#     Found existing installation: numba 0.62.1
#    ------------------------- -------------- 15/24 [patsy]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#     Uninstalling numba-0.62.1:
#    -------------------------- ------------- 16/24 [numba]
#       Successfully uninstalled numba-0.62.1
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#    -------------------------- ------------- 16/24 [numba]
#   Attempting uninstall: sparse
#    -------------------------- ------------- 16/24 [numba]
#     Found existing installation: sparse 0.17.0
#    -------------------------- ------------- 16/24 [numba]
#     Uninstalling sparse-0.17.0:
#    -------------------------- ------------- 16/24 [numba]
#       Successfully uninstalled sparse-0.17.0
#    -------------------------- ------------- 16/24 [numba]
#    ---------------------------- ----------- 17/24 [sparse]
#    ---------------------------- ----------- 17/24 [sparse]
#    ---------------------------- ----------- 17/24 [sparse]
#    ---------------------------- ----------- 17/24 [sparse]
#    ---------------------------- ----------- 17/24 [sparse]
#    ---------------------------- ----------- 17/24 [sparse]
#    ---------------------------- ----------- 17/24 [sparse]
#    ---------------------------- ----------- 17/24 [sparse]
#    ---------------------------- ----------- 17/24 [sparse]
#    ---------------------------- ----------- 17/24 [sparse]
#    ---------------------------- ----------- 17/24 [sparse]
#    ---------------------------- ----------- 17/24 [sparse]
#    ---------------------------- ----------- 17/24 [sparse]
#    ---------------------------- ----------- 17/24 [sparse]
#    ---------------------------- ----------- 17/24 [sparse]
# ...
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ----------------------------------- ---- 21/24 [statsmodels]
#   Attempting uninstall: shap
#    ----------------------------------- ---- 21/24 [statsmodels]
#     Found existing installation: shap 0.48.0
#    ----------------------------------- ---- 21/24 [statsmodels]
#    ------------------------------------ --- 22/24 [shap]
#     Uninstalling shap-0.48.0:
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#       Successfully uninstalled shap-0.48.0
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#    ------------------------------------ --- 22/24 [shap]
#   Attempting uninstall: econml
#    ------------------------------------ --- 22/24 [shap]
#     Found existing installation: econml 0.16.0
#    ------------------------------------ --- 22/24 [shap]
#     Uninstalling econml-0.16.0:
#    ------------------------------------ --- 22/24 [shap]
#       Successfully uninstalled econml-0.16.0
#    ------------------------------------ --- 22/24 [shap]
#    -------------------------------------- - 23/24 [econml]
#    -------------------------------------- - 23/24 [econml]
#    -------------------------------------- - 23/24 [econml]
#    -------------------------------------- - 23/24 [econml]
#    -------------------------------------- - 23/24 [econml]
#    -------------------------------------- - 23/24 [econml]
#    -------------------------------------- - 23/24 [econml]
#    -------------------------------------- - 23/24 [econml]
#    -------------------------------------- - 23/24 [econml]
#    -------------------------------------- - 23/24 [econml]
#    -------------------------------------- - 23/24 [econml]
#    -------------------------------------- - 23/24 [econml]
#    -------------------------------------- - 23/24 [econml]
#    -------------------------------------- - 23/24 [econml]
#    ---------------------------------------- 24/24 [econml]
#
# Successfully installed cloudpickle-3.1.2 colorama-0.4.6 econml-0.16.0 joblib-1.5.2 lightgbm-4.6.0 llvmlite-0.45.1 numba-0.62.1 numpy-2.3.4 packaging-25.0 pandas-2.3.3 patsy-1.0.2 python-dateutil-2.9.0.post0 pytz-2025.2 scikit-learn-1.6.1 scipy-1.16.3 shap-0.48.0 six-1.17.0 slicer-0.0.8 sparse-0.17.0 statsmodels-0.14.5 threadpoolctl-3.6.0 tqdm-4.67.1 typing-extensions-4.15.0 tzdata-2025.2
#   WARNING: Failed to remove contents in a temporary directory 'F:\anaconda3\envs\project1_env_fixed\Lib\site-packages\~-mpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'F:\anaconda3\envs\project1_env_fixed\Lib\site-packages\~-mpy'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'F:\anaconda3\envs\project1_env_fixed\Lib\site-packages\~-ipy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'F:\anaconda3\envs\project1_env_fixed\Lib\site-packages\~-ipy'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'F:\anaconda3\envs\project1_env_fixed\Lib\site-packages\~-learn'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'F:\anaconda3\envs\project1_env_fixed\Lib\site-packages\~-ndas'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dowhy 0.14 requires scipy<=1.15.3; python_version >= "3.9" and python_version < "3.13", but you have scipy 1.16.3 which is incompatible.

# %%
# Loading dataset 
data = pd.read_csv("../data/output_gpt2.csv")

# Creating categories automatically
import re
def categorize_prompt(text):
    text = str(text).lower()
    if re.search(r'\b(he|she|man|woman|boy|girl)\b', text):
        return "gender"
    elif re.search(r'\b(good|bad|moral|ethical|honest|dishonest)\b', text):
        return "moral"
    elif re.search(r'\b(what is|who is|define|explain|describe)\b', text):
        return "factual"
    elif re.search(r'\b(culture|tradition|art|music|society)\b', text):
        return "culture"
    else:
        return "neutral"

data["category"] = data["prompt_text"].apply(categorize_prompt)

from textblob import TextBlob
data["sentiment"] = data["model_output"].apply(lambda t: TextBlob(str(t)).sentiment.polarity)

# Binary treatment example: gender vs others
data["treatment"] = data["category"].apply(lambda c: 1 if c == "gender" else 0)

# %%
from IPython.display import Image, display
import graphviz

# causal assumptions
causal_graph = """
digraph {
    gender_treatment -> model_output_sentiment;
    gender_treatment -> prompt_text;
    prompt_text -> model_output_sentiment;
}
"""

display(graphviz.Source(causal_graph))

# %%
from dowhy import CausalModel

model = CausalModel(
    data=data,
    treatment='treatment',
    outcome='sentiment',
    graph='digraph{treatment -> sentiment;}'
)

identified = model.identify_effect()
estimate = model.estimate_effect(identified, method_name="backdoor.linear_regression")

print("Causal Effect Estimate (DoWhy):", estimate.value)
model.refute_estimate(identified, estimate, method_name="random_common_cause")
# Out:
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# Causal Effect Estimate (DoWhy): 0.0
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\statsmodels\regression\linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])

# %%
from econml.dml import LinearDML
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LassoCV
import numpy as np

# %%
import re

def detect_gender_prompt(text):
    text = str(text).lower()
    if re.search(r'\b(he|she|man|woman|boy|girl)\b', text):
        return 1
    else:
        return 0

data["treatment"] = data["prompt_text"].apply(detect_gender_prompt)
print(data["treatment"].value_counts())
# Out:
# treatment
# 0    300
# Name: count, dtype: int64

# %%
def detect_moral_prompt(text):
    text = str(text).lower()
    return 1 if re.search(r'\b(good|bad|moral|ethical|honest|dishonest)\b', text) else 0

data["treatment"] = data["prompt_text"].apply(detect_moral_prompt)
print(data["treatment"].value_counts())
# Out:
# treatment
# 0    293
# 1      7
# Name: count, dtype: int64

# %%
from econml.dml import LinearDML
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LassoCV
import numpy as np

# --- Define outcome, treatment ---
Y = data["sentiment"].values
T = data["treatment"].values

# --- Add some realistic confounders so the matrix isn’t singular ---
# If you don’t have real confounders, at least add random noise or prompt length
data["prompt_length"] = data["prompt_text"].apply(lambda t: len(str(t)))
data["prompt_sentiment"] = data["prompt_text"].apply(
    lambda t: TextBlob(str(t)).sentiment.polarity
)

# Combine multiple features to make X non-singular
X = data[["prompt_length", "prompt_sentiment"]].values

# --- Fit the model ---
est = LinearDML(
    model_y=RandomForestRegressor(),
    model_t=LassoCV(),
    random_state=42
)
print("Y shape:", Y.shape)
print("T unique:", np.unique(T))
print("X shape:", X.shape)
print("Any NaN in Y?", np.isnan(Y).any())
print("Any NaN in T?", np.isnan(T).any())
print("Any NaN in X?", np.isnan(X).any())

est.fit(Y, T, X=X)
treatment_effect = est.effect(X)
print("Average Treatment Effect (EconML):", np.mean(treatment_effect))
# Out:
# Y shape: (300,)
# T unique: [0 1]
# X shape: (300, 2)
# Any NaN in Y? False
# Any NaN in T? False
# Any NaN in X? False
# Average Treatment Effect (EconML): 0.15855126814824622

# %%
import seaborn as sns

sns.kdeplot(treatment_effect)
plt.title("Distribution of Estimated Treatment Effects (EconML)")
plt.xlabel("Effect on Sentiment")
plt.show()
plt.savefig("../results/Causal_analysis/GPT2/Distribution_of_EconML.png")

# %%
from textblob import TextBlob

# Outcome variable
data["sentiment"] = data["model_output"].apply(lambda t: TextBlob(str(t)).sentiment.polarity)

# Confounders
data["prompt_length"] = data["prompt_text"].apply(lambda t: len(str(t)))
data["prompt_sentiment"] = data["prompt_text"].apply(lambda t: TextBlob(str(t)).sentiment.polarity)

# Quick sanity check
print(data["treatment"].value_counts())


Y = data["sentiment"].values
T = data["treatment"].values
X = data[["prompt_length", "prompt_sentiment"]].values


from econml.dml import SparseLinearDML
from sklearn.ensemble import RandomForestRegressor

est = SparseLinearDML(
    model_y=RandomForestRegressor(n_estimators=200, random_state=42, min_samples_leaf=5),
    model_t=RandomForestRegressor(n_estimators=200, random_state=42, min_samples_leaf=5),
    random_state=42
)

est.fit(Y, T, X=X)
te = est.effect(X)
ate = np.mean(te)
print(f"Average Treatment Effect (ATE): {ate:.6f}")


import matplotlib.pyplot as plt

plt.hist(te, bins=20, color='orange', edgecolor='black')
plt.title("Distribution of Estimated Treatment Effects (EconML)")
plt.xlabel("Effect on Sentiment")
plt.ylabel("Count")
plt.tight_layout()
plt.show()
plt.savefig("../results/Causal_analysis/GPT2/Estimated_EconML.png")
# Out:
# treatment
# 0    293
# 1      7
# Name: count, dtype: int64
# f:\anaconda3\envs\project1_env_fixed\Lib\site-packages\econml\utilities.py:75: UserWarning: The number of features in the final model (< 5) is too small for a sparse model. We recommend using the LinearDML estimator for this low-dimensional setting.
#   warn(msg, UserWarning)
# Average Treatment Effect (ATE): -0.061361

# %% [markdown]
# ### what achieved from above ?
#
# 1. A stable causal estimation pipeline (SparseLinearDML)
#
# 2. Meaningful treatment variable with real variation
#
# 3. Sentiment-based bias measurement
#
# 4. Cross-model comparison capability
